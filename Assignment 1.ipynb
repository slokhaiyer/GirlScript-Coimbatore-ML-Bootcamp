# %%
# Program to display the number of days in a month
month = str(input("Enter Month as January/February/March/April/etc\n"))
year = int(input("Enter year\n"))
if(month == "January" or month == "March" or month == "May" or month == "July" or month == "August" or month == "October" or month == "December"):
	print("Number of days is 31")
elif((month == "February") and ((year%400==0) or (year%4==0 and year%100!=0))):	
	print("Number of days is 29")
elif(month == "February"):
	print(" of days is 28")
elif(month == "April" or month == "June" or month == "September" or month == "November"):
	print("Number of days is 30")
else:
  print("Please enter valid month")
# Out:
# Enter Month as January/February/March/April/etc
# 8
# Enter year
# 3000
# Please enter valid month
